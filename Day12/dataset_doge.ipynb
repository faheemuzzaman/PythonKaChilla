# %% [markdown]
# # This is my Day 12 Training
# In this notebook I have to write the code about Pandas with dataset
# - This is the first task
# - This is the first task
# - This is the first task

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
col_list = ["date","marketcap(USD)","price(USD)", "generatedCoins","fees"]
df = pd.read_csv('dogecoin.csv',usecols=col_list)
# data_set.mean()
df.groupby(["marketcap(USD)","price(USD)"]).mean()
# data_set.describe()
# data_set.mean()
# data_set['generatedCoins', 'fees']
y = df['marketcap(USD)']
x = df['price(USD)']

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf()

# plt.show()
